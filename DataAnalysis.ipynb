# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Tulu Dataset

# %%
df = pd.read_csv('/Users/emmanuelgeorgep/Documents/Paper/Code/Data/Tulu-SA-train.csv') 
df.head()
# Out:
#                                                 Text     Label
# 0                          Aunty log bohot kadak hai  Not Tulu
# 1  Shruthi was awesome... Nice collaboration... H...  Not Tulu
# 2                  Gol gappadh ammana sajjigene best  Positive
# 3                 Chaddida brand thojodijji marre😃😃😃   Neutral
# 4                     Memories just got refreshed...  Not Tulu

# %%
label_counts = df['Label'].value_counts()
label_counts
# Out:
# Label
# Not Tulu         4401
# Positive         3770
# Neutral          3175
# Mixed            1114
# Negative          846
# unknown_state       2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=label_counts.index, y=label_counts.values, palette='viridis')
plt.title('Number of Samples per Label')
plt.xlabel('Label')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tamil Dataset

# %%
df = pd.read_csv('/Users/emmanuelgeorgep/Documents/Paper/Code/Data/Tam-SA-train.csv') 
df.head()
# Out:
#                                                 Text          Label
# 0        Ennq pa idhu paei padama twist nalla irkkae       Positive
# 1  Na oru thalaivar veriyan....intha padam pakanu...  unknown_state
# 2       last shot apdiye moratu kaala paatha feeling       Positive
# 3       Darbar motion poster see after petta trailer  unknown_state
# 4  ln 9 minutes 88k likes , Ajith sir fans like h...       Positive

# %%
label_counts = df['Label'].value_counts()
label_counts
# Out:
# Label
# Positive          18145
# unknown_state      5164
# Negative           4151
# Mixed_feelings     3662
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=label_counts.index, y=label_counts.values, palette='viridis')
plt.title('Number of Samples per Label')
plt.xlabel('Label')
plt.ylabel('Number of Samples')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
